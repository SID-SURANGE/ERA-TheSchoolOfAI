# %% [markdown]
# <h3> Session 8 </h4>
#
# <I>

# %% [markdown]
# ### Imports <hr>

# %%
# Pytorch imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchsummary import summary
from torch.optim.lr_scheduler import MultiStepLR


import sys
sys.path.append('../')

# Loading classes from py files
from model import Net
from utils import Utility
from constants import *
from dataset import *
from transforms import *
from train import train, test, plot_loss_accuracy, plot_misclassified
from misclassified import *

# %% [markdown]
# Class Object Initialization

# %%
# creating class objects
get_utilitites= Utility()

# %% [markdown]
# ##### Check device support CPU/GPU <hr>

# %%
device = Utility.set_cuda_if_available()

print(f'Device available for the script - {device}')
# Out:
# CUDA Available? <function is_available at 0x00000224BACFC310>
# Device available for the script - cuda

# %% [markdown]
# ##### Create Batch loader for train/test dataset  <hr>

# %%
get_data = Dataset(batch_size=64)

train_loader = get_data.train_loader()
test_loader = get_data.test_loader()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Analyze the first batch of 512 images
images, labels = next(iter(train_loader))
print(f'Shape of the batch - {images.shape}')
print(f'Total images in the batch - {len(labels)}')
# Out:
# Shape of the batch - torch.Size([64, 3, 32, 32])
# Total images in the batch - 64

# %% [markdown]
# ##### View sample images from the train loader  <hr>

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

#get_utilitites.plot_grid(train_loader)
get_utilitites.show_batch(train_loader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ##### CNN Model summary  <hr>

# %%
model = Net(normalization='bn').to(device)

summary(model, input_size=(3, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 24, 28, 28]             648
#               ReLU-2           [-1, 24, 28, 28]               0
#        BatchNorm2d-3           [-1, 24, 28, 28]              48
#            Dropout-4           [-1, 24, 28, 28]               0
#             Conv2d-5           [-1, 24, 28, 28]           5,184
#               ReLU-6           [-1, 24, 28, 28]               0
#        BatchNorm2d-7           [-1, 24, 28, 28]              48
#            Dropout-8           [-1, 24, 28, 28]               0
#             Conv2d-9           [-1, 16, 28, 28]             384
#              ReLU-10           [-1, 16, 28, 28]               0
#         MaxPool2d-11           [-1, 16, 14, 14]               0
#            Conv2d-12           [-1, 24, 14, 14]           3,456
#              ReLU-13           [-1, 24, 14, 14]               0
#       BatchNorm2d-14           [-1, 24, 14, 14]              48
#           Dropout-15           [-1, 24, 14, 14]               0
#            Conv2d-16           [-1, 24, 14, 14]           5,184
#              ReLU-17           [-1, 24, 14, 14]               0
#       BatchNorm2d-18           [-1, 24, 14, 14]              48
#           Dropout-19           [-1, 24, 14, 14]               0
#            Conv2d-20           [-1, 32, 14, 14]           6,912
#              ReLU-21           [-1, 32, 14, 14]               0
#       BatchNorm2d-22           [-1, 32, 14, 14]              64
#           Dropout-23           [-1, 32, 14, 14]               0
#            Conv2d-24           [-1, 16, 14, 14]             512
#              ReLU-25           [-1, 16, 14, 14]               0
#         MaxPool2d-26             [-1, 16, 7, 7]               0
#            Conv2d-27             [-1, 24, 5, 5]           3,456
#              ReLU-28             [-1, 24, 5, 5]               0
#       BatchNorm2d-29             [-1, 24, 5, 5]              48
#           Dropout-30             [-1, 24, 5, 5]               0
#            Conv2d-31             [-1, 24, 3, 3]           5,184
#              ReLU-32             [-1, 24, 3, 3]               0
#       BatchNorm2d-33             [-1, 24, 3, 3]              48
#           Dropout-34             [-1, 24, 3, 3]               0
#            Conv2d-35             [-1, 32, 3, 3]           6,912
#              ReLU-36             [-1, 32, 3, 3]               0
#       BatchNorm2d-37             [-1, 32, 3, 3]              64
#           Dropout-38             [-1, 32, 3, 3]               0
#         AvgPool2d-39             [-1, 32, 1, 1]               0
#            Conv2d-40             [-1, 10, 1, 1]             320
# ================================================================
# Total params: 38,568
# Trainable params: 38,568
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.93
# Params size (MB): 0.15
# Estimated Total Size (MB): 2.09
# ----------------------------------------------------------------

# %% [markdown]
# #### Let's Train and test our model
# ---

# %%
# variable for model and training
num_epochs = 20
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=0.001)

#scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1, verbose=True)
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3)
scheduler = MultiStepLR(optimizer, milestones=[9,14], gamma=0.1)


for epoch in range(1, num_epochs+1):
  print(f'Epoch {epoch}')
  train(model, device, train_loader, optimizer)
  test_loss = test(model, device, test_loader)
  scheduler.step()
# Out:
# Epoch 1
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 1.2666, Accuracy: 5374/10000 (53.74%)
#
# Epoch 2
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.9917, Accuracy: 6398/10000 (63.98%)
#
# Epoch 3
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.9470, Accuracy: 6704/10000 (67.04%)
#
# Epoch 4
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.8337, Accuracy: 7129/10000 (71.29%)
#
# Epoch 5
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.7975, Accuracy: 7208/10000 (72.08%)
#
# Epoch 6
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.7476, Accuracy: 7377/10000 (73.77%)
#
# Epoch 7
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.7798, Accuracy: 7268/10000 (72.68%)
#
# Epoch 8
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.7095, Accuracy: 7488/10000 (74.88%)
#
# Epoch 9
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.7538, Accuracy: 7377/10000 (73.77%)
#
# Epoch 10
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.6204, Accuracy: 7836/10000 (78.36%)
#
# Epoch 11
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.6100, Accuracy: 7888/10000 (78.88%)
#
# Epoch 12
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.6077, Accuracy: 7916/10000 (79.16%)
#
# Epoch 13
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.5972, Accuracy: 7958/10000 (79.58%)
#
# Epoch 14
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.5993, Accuracy: 7929/10000 (79.29%)
#
# Epoch 15
#   0%|          | 0/782 [00:06<?, ?it/s]
# Test set: Average loss: 0.5888, Accuracy: 7974/10000 (79.74%)
#
# Epoch 16
#   0%|          | 0/782 [00:06<?, ?it/s]
# Test set: Average loss: 0.5921, Accuracy: 7976/10000 (79.76%)
#
# Epoch 17
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.5873, Accuracy: 7987/10000 (79.87%)
#
# Epoch 18
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.5865, Accuracy: 7971/10000 (79.71%)
#
# Epoch 19
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.5856, Accuracy: 7989/10000 (79.89%)
#
# Epoch 20
#   0%|          | 0/782 [00:03<?, ?it/s]
# Test set: Average loss: 0.5860, Accuracy: 7998/10000 (79.98%)

# %% [markdown]
# Plot the Loss/Accuracy for Train/Test dataset

# %%
plot_loss_accuracy()

# %%
images, actuals, preds = test_misclassified(model,device,test_loader)
plot_images(images, actuals, preds, classes)
