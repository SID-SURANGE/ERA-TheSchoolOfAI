# %% [markdown]
# <h3> Session 8 </h4>
#
# <I>

# %% [markdown]
# ### Imports <hr>

# %%
# Pytorch imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchsummary import summary
from torch.optim.lr_scheduler import MultiStepLR


import sys
sys.path.append('../')

# Loading classes from py files
from model import Net
from utils import Utility
from constants import *
from dataset import *
from transforms import *
from train import train, test, plot_loss_accuracy, plot_misclassified
from misclassified import *
from torch_lr_finder import LRFinder

# %% [markdown]
# Class Object Initialization

# %%
# creating class objects
get_utilitites= Utility()

# %% [markdown]
# ##### Check device support CPU/GPU <hr>

# %%
device = Utility.set_cuda_if_available()

print(f'Device available for the script - {device}')
# Out:
# CUDA Available? <function is_available at 0x00000160C54AC310>
# Device available for the script - cuda

# %% [markdown]
# ##### Create Batch loader for train/test dataset  <hr>

# %%
get_data = Dataset(batch_size=64)

train_loader = get_data.train_loader()
test_loader = get_data.test_loader()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Analyze the first batch of 512 images
images, labels = next(iter(train_loader))
print(f'Shape of the batch - {images.shape}')
print(f'Total images in the batch - {len(labels)}')
# Out:
# Shape of the batch - torch.Size([64, 3, 32, 32])
# Total images in the batch - 64

# %% [markdown]
# ##### View sample images from the train loader  <hr>

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

#get_utilitites.plot_grid(train_loader)
get_utilitites.show_batch(train_loader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ##### CNN Model summary  <hr>

# %%
model = Net(normalization='bn').to(device)

summary(model, input_size=(3, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 28, 28]           1,728
#        BatchNorm2d-2           [-1, 64, 28, 28]             128
#               ReLU-3           [-1, 64, 28, 28]               0
#            Dropout-4           [-1, 64, 28, 28]               0
#             Conv2d-5          [-1, 128, 28, 28]          73,728
#          MaxPool2d-6          [-1, 128, 14, 14]               0
#        BatchNorm2d-7          [-1, 128, 14, 14]             256
#               ReLU-8          [-1, 128, 14, 14]               0
#            Dropout-9          [-1, 128, 14, 14]               0
#            Conv2d-10           [-1, 64, 14, 14]          73,728
#       BatchNorm2d-11           [-1, 64, 14, 14]             128
#              ReLU-12           [-1, 64, 14, 14]               0
#           Dropout-13           [-1, 64, 14, 14]               0
#            Conv2d-14          [-1, 128, 14, 14]          73,728
#       BatchNorm2d-15          [-1, 128, 14, 14]             256
#              ReLU-16          [-1, 128, 14, 14]               0
#           Dropout-17          [-1, 128, 14, 14]               0
#            Conv2d-18          [-1, 256, 14, 14]         294,912
#         MaxPool2d-19            [-1, 256, 7, 7]               0
#       BatchNorm2d-20            [-1, 256, 7, 7]             512
#              ReLU-21            [-1, 256, 7, 7]               0
#           Dropout-22            [-1, 256, 7, 7]               0
#            Conv2d-23            [-1, 512, 7, 7]       1,179,648
#         MaxPool2d-24            [-1, 512, 3, 3]               0
#       BatchNorm2d-25            [-1, 512, 3, 3]           1,024
#              ReLU-26            [-1, 512, 3, 3]               0
#           Dropout-27            [-1, 512, 3, 3]               0
#            Conv2d-28            [-1, 256, 3, 3]       1,179,648
#       BatchNorm2d-29            [-1, 256, 3, 3]             512
#              ReLU-30            [-1, 256, 3, 3]               0
#           Dropout-31            [-1, 256, 3, 3]               0
#            Conv2d-32            [-1, 512, 3, 3]       1,179,648
#       BatchNorm2d-33            [-1, 512, 3, 3]           1,024
#              ReLU-34            [-1, 512, 3, 3]               0
#           Dropout-35            [-1, 512, 3, 3]               0
#         MaxPool2d-36            [-1, 512, 1, 1]               0
#            Conv2d-37             [-1, 10, 1, 1]           5,120
# ================================================================
# Total params: 4,065,728
# Trainable params: 4,065,728
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.52
# Params size (MB): 15.51
# Estimated Total Size (MB): 21.04
# ----------------------------------------------------------------

# %% [markdown]
# #### Let's Train and test our model
# ---

# %%
# LR FINDER
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.1, weight_decay=1e-2)
lr_finder = LRFinder(model, optimizer, criterion, device="cuda")
lr_finder.range_test(train_loader, val_loader=test_loader, end_lr=1, num_iter=100, step_mode="linear")
lr_finder.plot(log_lr=False)
lr_finder.reset()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       3 optimizer = optim.Adam(model.parameters(), lr=0.1, weight_decay=1e-2)
#       4 lr_finder = LRFinder(model, optimizer, criterion, device="cuda")
# ----> 5 lr_finder.range_test(train_loader, val_loader=test_loader, end_lr=1, num_iter=100, step_mode="linear")
#       6 lr_finder.plot(log_lr=False)
#       7 lr_finder.reset()
#
# File e:\Softwares\Apps\Anaconda\envs\era\lib\site-packages\torch_lr_finder\lr_finder.py:323, in LRFinder.range_test(self, train_loader, val_loader, start_lr, end_lr, num_iter, step_mode, smooth_f, diverge_th, accumulation_steps, non_blocking_transfer)
#     317 loss = self._train_batch(
#     318     train_iter,
#     319     accumulation_steps,
#     320     non_blocking_transfer=non_blocking_transfer,
#     321 )
#     322 if val_loader:
# --> 323     loss = self._validate(
#     324         val_iter, non_blocking_transfer=non_blocking_transfer
#     325     )
#     327 # Update the learning rate
#     328 self.history["lr"].append(lr_schedule.get_lr()[0])
#
# File e:\Softwares\Apps\Anaconda\envs\era\lib\site-packages\torch_lr_finder\lr_finder.py:427, in LRFinder._validate(self, val_iter, non_blocking_transfer)
#     425 self.model.eval()
#     426 with torch.no_grad():
# --> 427     for inputs, labels in val_iter:
#     428         # Move data to the correct device
#     429         inputs, labels = self._move_to_device(
#     430             inputs, labels, non_blocking=non_blocking_transfer
#     431         )
#     433         # Forward pass and loss computation
#
# File e:\Softwares\Apps\Anaconda\envs\era\lib\site-packages\torch_lr_finder\lr_finder.py:98, in ValDataLoaderIter.__iter__(self)
#      96 def __iter__(self):
#      97     if self.run_counter >= self.run_limit:
# ---> 98         self._iterator = iter(self.data_loader)
#      99         self.run_counter = 0
#     100     return self
#
# File e:\Softwares\Apps\Anaconda\envs\era\lib\site-packages\torch\utils\data\dataloader.py:441, in DataLoader.__iter__(self)
#     439     return self._iterator
#     440 else:
# --> 441     return self._get_iterator()
#
# File e:\Softwares\Apps\Anaconda\envs\era\lib\site-packages\torch\utils\data\dataloader.py:388, in DataLoader._get_iterator(self)
#     386 else:
#     387     self.check_worker_number_rationality()
# --> 388     return _MultiProcessingDataLoaderIter(self)
#
# File e:\Softwares\Apps\Anaconda\envs\era\lib\site-packages\torch\utils\data\dataloader.py:1042, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1035 w.daemon = True
#    1036 # NB: Process.start() actually take some time as it needs to
#    1037 #     start a process and pass the arguments over via a pipe.
#    1038 #     Therefore, we only add a worker to self._workers list after
#    1039 #     it started, so that we do not call .join() if program dies
#    1040 #     before it starts, and __del__ tries to join but will get:
#    1041 #     AssertionError: can only join a started process.
# -> 1042 w.start()
#    1043 self._index_queues.append(index_queue)
#    1044 self._workers.append(w)
#
# File e:\Softwares\Apps\Anaconda\envs\era\lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File e:\Softwares\Apps\Anaconda\envs\era\lib\multiprocessing\context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File e:\Softwares\Apps\Anaconda\envs\era\lib\multiprocessing\context.py:336, in SpawnProcess._Popen(process_obj)
#     333 @staticmethod
#     334 def _Popen(process_obj):
#     335     from .popen_spawn_win32 import Popen
# --> 336     return Popen(process_obj)
#
# File e:\Softwares\Apps\Anaconda\envs\era\lib\multiprocessing\popen_spawn_win32.py:93, in Popen.__init__(self, process_obj)
#      91 try:
#      92     reduction.dump(prep_data, to_child)
# ---> 93     reduction.dump(process_obj, to_child)
#      94 finally:
#      95     set_spawning_popen(None)
#
# File e:\Softwares\Apps\Anaconda\envs\era\lib\multiprocessing\reduction.py:60, in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#
# KeyboardInterrupt:

# %%
# variable for model and training
num_epochs = 15
optimizer = optim.Adam(model.parameters(), lr=0.01, momentum=0.9, weight_decay=0.001)

#scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1, verbose=True)
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3)
scheduler = MultiStepLR(optimizer, milestones=[8,12], gamma=0.1)


for epoch in range(1, num_epochs+1):
  print(f'Epoch {epoch}')
  train(model, device, train_loader, optimizer)
  test(model, device, test_loader)
  scheduler.step()
# Out:
# Epoch 1
#   0%|          | 0/782 [00:04<?, ?it/s]
# Test set: Average loss: 1.0052, Accuracy: 6467/10000 (64.67%)
#
# Epoch 2
#   0%|          | 0/782 [00:04<?, ?it/s]
# Test set: Average loss: 0.6526, Accuracy: 7751/10000 (77.51%)
#
# Epoch 3
#   0%|          | 0/782 [00:04<?, ?it/s]

# %% [markdown]
# Plot the Loss/Accuracy for Train/Test dataset

# %%
plot_loss_accuracy()

# %% [markdown]
# Plot misclassified images

# %%
images, actuals, preds = test_misclassified(model,device,test_loader)
plot_images(images, actuals, preds, classes)
